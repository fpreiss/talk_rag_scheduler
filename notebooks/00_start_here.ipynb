# %% [markdown]
# # Start Here
#
# ## Indexing
#
# * [indexing notebook](./01_indexing.ipynb)
# * [indexing code](../src/talk_rag_scheduler/indexing_pipeline.py)
#
# Run from cli:
#
# ```bash
# python -m talk_rag_scheduler.indexing_pipeline --indexing_mode semantic
# ```
#
# ## Retrieval
#
# ### BM25
#
# * [bm25 retrieval notebook](./02a_retrieval_bm25.ipynb)
# * [retrieval code](../src/talk_rag_scheduler/retrieval_pipeline.py)
#
# Run from cli:
#
# ```bash
# python -m talk_rag_scheduler.retrieval_pipeline | rich - --markdown
# ```
#
# ### Semantic Search
#
# * [vector retrieval notebook](./02b_retrieval_vector.ipynb)
# * [retrieval code](../src/talk_rag_scheduler/retrieval_pipeline.py)
#
# Run from cli:
#
# ```bash
# python -m talk_rag_scheduler.retrieval_pipeline --indexing_mode semantic | rich - --markdown
# ```
#
# ## Rag Pipeline
#
# ### Simple Rag Pipeline
#
# * [simple rag notebook](./03a_rag.ipynb)
# * [simple rag code](../src/talk_rag_scheduler/rag_pipeline.py)
#
# Run from cli:
#
# ```bash
# python -m talk_rag_scheduler.rag_pipeline "What are the features of the scheduler?" --indexing_mode semantic_split
# ```
#
# ### Concurrent Rag Pipeline
#
# * [concurrent rag notebook](./03b_rag_concurrent.ipynb)
# * [concurrent rag code](../src/talk_rag_scheduler/rag_pipeline_concurrent.py)
#
#
# Run from cli:
#
# ```bash
# python -m talk_rag_scheduler.rag_pipeline_concurrent "What are the features of the scheduler?" --n_concurrent 5 | rich - --markdown
# ```
#
# ## Evaluation
#
# * [benchmark retriever notebook](./04_retrieval_bench.ipynb)
# * [benchmark retriever code](../src/talk_rag_scheduler/bench_retrieval.py)
#
# Run from cli:
#
# ```bash
# python -m talk_rag_scheduler.bench_retrieval
# ```
